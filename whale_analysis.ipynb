# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")
whale_df= pd.read_csv(whale_returns_csv,index_col='Date',
                      infer_datetime_format=True,
                      parse_dates=True)

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_df= pd.read_csv(algo_returns_csv,
                    index_col='Date',
                    infer_datetime_format=True,
                    parse_dates=True)

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices, sorting index
sp500_history_csv = Path("Resources/sp500_history.csv")
sp500_df=pd.read_csv(sp500_history_csv,
                    index_col="Date",
                    infer_datetime_format=True,
                    parse_dates=True)

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df['Close']= sp500_df['Close'].str.replace("$","").astype(float)

# %%
# Calculate Daily Returns
sp500_df= sp500_df.pct_change()
sp500_df
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
sp500_df.dropna(inplace=True)

# %%
# Rename Column
sp500_df.rename(columns={'Close':"SP500"},inplace=True)
sp500_df
# Out:
#                SP500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
combined_df=pd.concat([whale_df,algo_df,sp500_df],
                      axis="columns",
                     join="inner")
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns.

# %%
# Plot daily returns
combined_df.plot(figsize=(30,15))

# %%
# Plot cumulative returns
combined_df.cumsum().plot(figsize=(30,15))

# %% [markdown]
# ---

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
combined_df.plot.box(figsize=(30,15))

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. Which portfolios are riskier than the S&P 500?
std_df=combined_df.std()
std_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# SP500                          0.008587
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_df=combined_df.std()*np.sqrt(252)
annualized_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SP500                          0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 2. Calculate and plot a 60 day Beta for Berkshire Hathaway Inc compared to the S&&P 500

# %%
# Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
rolling_df=combined_df.rolling(window=21).std().plot(figsize=(30,10))
rolling_df

# %%
# Correlation
correlation_df=combined_df.corr()
sns.heatmap(correlation_df,vmin=-1,vmax=1)

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
covariance= combined_df["Algo 1"].cov(combined_df["SP500"])
variance= combined_df["SP500"].var()
algo_beta= covariance/variance
rolling_algol_covariance= combined_df["Algo 1"].rolling(window=60).cov(combined_df["SP500"])
rolling_variance= combined_df["SP500"].rolling(window=60).var()
rolling_algol_beta= rolling_algol_covariance/rolling_variance
rolling_beta_plot= rolling_algol_beta.plot(figsize=(20,10))
print(algo_beta)
print(rolling_beta_plot)
# Out:
# -0.030149214542337772
# AxesSubplot(0.125,0.2;0.775x0.68)

# %% [markdown]
# ### Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rollwing window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the `ewm` with a 21 day half-life.

# %%
# (OPTIONAL) YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# Calculate and plot the annualized Sharpe ratios for all portfolios to determine which portfolio has the best performance

# %%
# Annualzied Sharpe Ratios
annualized_sharpe_df = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
annualized_sharpe_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# SP500                         -0.518582
# dtype: float64

# %% [markdown]
#  plot() these sharpe ratios using a barplot.
#  On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?

# %%
# Visualize the sharpe ratios as a bar plot
annualized_sharpe_df.plot(kind="bar")

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
BYND_csv = Path("Resources/BYND_google_fin.csv")
BYND_df = pd.read_csv(BYND_csv,
                      index_col='Date',
                      infer_datetime_format=True,
                      parse_dates=True)
BYND_df.head()
# Out:
#             Close
# Date
# 2019-05-02  65.75
# 2019-05-03  66.79
# 2019-05-06  74.79
# 2019-05-07  79.17
# 2019-05-08  72.25

# %%
# Read the second stock
BIP_csv = Path("Resources/BIP_google_fin.csv")
BIP_df = pd.read_csv(BIP_csv,
                      index_col='Date',
                      infer_datetime_format=True,
                      parse_dates=True)
BIP_df.head()
# Out:
#             Close
# Date
# 2019-01-02  34.96
# 2019-01-03  35.40
# 2019-01-04  36.08
# 2019-01-07  36.77
# 2019-01-08  37.06

# %%
# Read the third stock
CGC_csv = Path("Resources/CGC_google_fin.csv")
CGC_df = pd.read_csv(CGC_csv,
                      index_col='Date',
                      infer_datetime_format=True,
                      parse_dates=True)
CGC_df.head()
# Out:
#             Close
# Date
# 2019-01-02  28.92
# 2019-01-03  28.11
# 2019-01-04  28.23
# 2019-01-07  28.90
# 2019-01-08  29.64

# %%
# Concatenate all stocks into a single DataFrame
Fin_portfolio_df = pd.concat([BYND_df, BIP_df, CGC_df],
                             axis="columns",
                             join="inner"
)
Fin_portfolio_df.columns = ["Beyond Meat",
                                "Brookfield Infrastructure",
                                "Canopy Growth"]
Fin_portfolio_df
# Out:
#             Beyond Meat  Brookfield Infrastructure  Canopy Growth
# Date
# 2019-05-02        65.75                      41.10          48.46
# 2019-05-03        66.79                      41.70          49.08
# 2019-05-06        74.79                      41.65          49.20
# 2019-05-07        79.17                      41.28          47.55
# 2019-05-08        72.25                      41.28          48.04
# ...                 ...                        ...            ...
# 2019-12-23        77.74                      49.14          19.74
# 2019-12-24        77.73                      49.63          19.96
# 2019-12-26        76.40                      49.89          19.22
# 2019-12-27        75.64                      50.14          19.21
# 2019-12-30        74.15                      49.58          18.79
#
# [168 rows x 3 columns]

# %%
# Reset the index
Fin_portfolio_df.reset_index()
Fin_portfolio_df
# Out:
#             Beyond Meat  Brookfield Infrastructure  Canopy Growth
# Date
# 2019-05-02        65.75                      41.10          48.46
# 2019-05-03        66.79                      41.70          49.08
# 2019-05-06        74.79                      41.65          49.20
# 2019-05-07        79.17                      41.28          47.55
# 2019-05-08        72.25                      41.28          48.04
# ...                 ...                        ...            ...
# 2019-12-23        77.74                      49.14          19.74
# 2019-12-24        77.73                      49.63          19.96
# 2019-12-26        76.40                      49.89          19.22
# 2019-12-27        75.64                      50.14          19.21
# 2019-12-30        74.15                      49.58          18.79
#
# [168 rows x 3 columns]

# %%
# Drop Nulls
Fin_portfolio_df.dropna(inplace=True)
Fin_portfolio_df
# Out:
#             Beyond Meat  Brookfield Infrastructure  Canopy Growth
# Date
# 2019-05-02        65.75                      41.10          48.46
# 2019-05-03        66.79                      41.70          49.08
# 2019-05-06        74.79                      41.65          49.20
# 2019-05-07        79.17                      41.28          47.55
# 2019-05-08        72.25                      41.28          48.04
# ...                 ...                        ...            ...
# 2019-12-23        77.74                      49.14          19.74
# 2019-12-24        77.73                      49.63          19.96
# 2019-12-26        76.40                      49.89          19.22
# 2019-12-27        75.64                      50.14          19.21
# 2019-12-30        74.15                      49.58          18.79
#
# [168 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
Fin_portfolio_returns_df = Fin_portfolio_df.pct_change()
Fin_portfolio_returns_df.dropna(inplace=True)
Fin_portfolio_returns_df
# Out:
#             Beyond Meat  Brookfield Infrastructure  Canopy Growth
# Date
# 2019-05-03     0.015817                   0.014599       0.012794
# 2019-05-06     0.119778                  -0.001199       0.002445
# 2019-05-07     0.058564                  -0.008884      -0.033537
# 2019-05-08    -0.087407                   0.000000       0.010305
# 2019-05-09    -0.055087                   0.003149      -0.024355
# ...                 ...                        ...            ...
# 2019-12-23     0.011713                   0.016129      -0.014970
# 2019-12-24    -0.000129                   0.009972       0.011145
# 2019-12-26    -0.017111                   0.005239      -0.037074
# 2019-12-27    -0.009948                   0.005011      -0.000520
# 2019-12-30    -0.019699                  -0.011169      -0.021864
#
# [167 rows x 3 columns]

# %%
weights = [1/3, 1/3, 1/3]
Agg_Fin_portfolio_returns_df = Fin_portfolio_returns_df.dot(weights)
Agg_Fin_portfolio_returns_df
# Out:
# Date
# 2019-05-03    0.014403
# 2019-05-06    0.040341
# 2019-05-07    0.005381
# 2019-05-08   -0.025701
# 2019-05-09   -0.025431
#                 ...
# 2019-12-23    0.004291
# 2019-12-24    0.006996
# 2019-12-26   -0.016315
# 2019-12-27   -0.001819
# 2019-12-30   -0.017577
# Length: 167, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
new_combined_df= combined_df[:167]

# %%
combined_df.shape
# Out:
# (1042, 7)

# %%
1042-168
# Out:
# 874

# %%
combined_df[874:]
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-08-20                   0.001651            0.007360
# 2018-08-21                   0.010695            0.006844
# 2018-08-22                   0.001132           -0.002784
# 2018-08-23                  -0.004628           -0.005066
# 2018-08-24                   0.006674            0.004229
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-08-20                    -0.000322                0.009380  0.001310
# 2018-08-21                    -0.007704                0.010368  0.002226
# ...

# %%
new_combined_df.shape
# Out:
# (167, 7)

# %%
combined_df[875:].shape
# Out:
# (167, 7)

# %%
Agg_Fin_portfolio_returns_df.shape
# Out:
# (167,)

# %%
pd.DataFrame(Agg_Fin_portfolio_returns_df)
# Out:
#                    0
# Date
# 2019-05-03  0.014403
# 2019-05-06  0.040341
# 2019-05-07  0.005381
# 2019-05-08 -0.025701
# 2019-05-09 -0.025431
# ...              ...
# 2019-12-23  0.004291
# 2019-12-24  0.006996
# 2019-12-26 -0.016315
# 2019-12-27 -0.001819
# 2019-12-30 -0.017577
#
# [167 rows x 1 columns]

# %%
pd.DataFrame(new_combined_df)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2015-10-21                  -0.013934           -0.010111
# 2015-10-22                   0.009900           -0.008222
# 2015-10-23                   0.012022            0.018284
# 2015-10-26                   0.005491            0.003900
# 2015-10-27                  -0.010448            0.003750
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
Agg_Fin_portfolio_returns_df.head()
# Out:
# Date
# 2019-05-03    0.014403
# 2019-05-06    0.040341
# 2019-05-07    0.005381
# 2019-05-08   -0.025701
# 2019-05-09   -0.025431
# dtype: float64

# %%
all_returns_df = pd.concat([pd.DataFrame(combined_df[874:]),pd.DataFrame(Agg_Fin_portfolio_returns_df)],
                         axis=1)
all_returns_df.dropna(inplace= True)

# %%
all_returns_df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_cumulative_returns = (1 + all_returns_df).cumprod() - 1
combined_cumulative_returns                                 title = "Returns of Portfolios").plot(kind = 'line',
                                 figsize=(25,10),
# Out:
#   File "<ipython-input-260-702c85ce5fad>", line 3
#     combined_cumulative_returns                                 title = "Returns of Portfolios").plot(kind = 'line',
#                                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
all_returns_df.plot.box(figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-261-62a1e1ab6427> in <module>
#       1 # Risk
# ----> 2 all_returns_df.plot.box(figsize=(20,10))
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in box(self, by, **kwargs)
#    1076             >>> ax = df.plot.box()
#    1077         """
# -> 1078         return self(kind="box", by=by, **kwargs)
#    1079
#    1080     def hist(self, by=None, bins=10, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...

# %%
# Rolling
all_rolling_std_df = all_returns_df.rolling(window=21).std().plot(figsize=(20,10))
all_rolling_std_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-262-daf165665f43> in <module>
#       1 # Rolling
# ----> 2 all_rolling_std_df = all_returns_df.rolling(window=21).std().plot(figsize=(20,10))
#       3 all_rolling_std_df
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ...

# %%
# Beta
covariance = all_returns_df["Benjamin Enterprise"].cov(all_returns_df["SP500"])
variance = all_returns_df["SP500"].var()
fintech_beta = covariance / variance
rolling_fintech_covariance = all_returns_df["Benjamin Enterprise"].rolling(window=60).cov(all_returns_df["SP500"])
rolling_variance_all = all_returns_df["SP500"].rolling(window=60).var()
rolling_fintech_beta = rolling_fintech_covariance / rolling_variance_all
rolling_beta_plot_all = rolling_fintech_beta.plot(figsize=(20, 10))
print(fintech_beta)
print(rolling_beta_plot_all)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Benjamin Enterprise'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-263-a9ccbee3cb42> in <module>
#       1 # Beta
# ...

# %%
# Annualzied Sharpe Ratios
annualized_sharpe_all_df = (all_returns_df.mean() * 252) / (all_returns_df.std() * np.sqrt(252))
annualized_sharpe_all_df
# Out:
# SOROS FUND MANAGEMENT LLC     NaN
# PAULSON & CO.INC.             NaN
# TIGER GLOBAL MANAGEMENT LLC   NaN
# BERKSHIRE HATHAWAY INC        NaN
# Algo 1                        NaN
# Algo 2                        NaN
# SP500                         NaN
# 0                             NaN
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
annualized_sharpe_all_df.plot(kind="bar")

# %% [markdown]
# ## Include correlation analysis to determine which stocks (if any) are correlated

# %%
correlation = all_returns_df.corr()
sns.heatmap(correlation, vmin=-1, vmax=1)
